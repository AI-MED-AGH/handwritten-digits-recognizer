# %% [markdown]
# # Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms

from os import path

from torch.utils.data import TensorDataset

from utils.plot import plot_digit_histograms

from scipy.ndimage import center_of_mass, shift

from sklearn.model_selection import StratifiedShuffleSplit

# %%
# Setting torch seed
random_seed = 42
torch.manual_seed(random_seed)

# %% [markdown]
# # Import fine tunning data

# %%
PATH = "fine-tuning-data-collector/fine_tune_data.csv"

line_data = np.genfromtxt(PATH, delimiter=',')

line_data = line_data[1:]

true_labels = np.array([d[0] for d in line_data], dtype=np.float32)
# Reshape, normalize in one line
data = np.array([(np.array(d[1:], dtype=np.float32) / 255.0).reshape((28, 28)) for d in line_data])

# Center image
centered_images = []
for img in data:
    if img.sum() < 1e-5:
        centered_images.append(img)
        continue

    c_y, c_x = center_of_mass(img)

    shift_x = 13.5 - c_x
    shift_y = 13.5 - c_y

    centered_image = shift(img, shift=(shift_y, shift_x), cval=0.0)
    centered_images.append(centered_image)

fig, axes = plt.subplots(2, 3, figsize=(9, 6))
axes = axes.flatten()

for i in range(6):
    ax = axes[i]
    ax.imshow(centered_images[i], cmap='gray', vmin=0, vmax=1)
    ax.set_title(f"True Label: {true_labels[i]}")
    ax.axis('off')

plt.tight_layout()
plt.savefig("six_images_subplots.png")

# %% [markdown]
# # Dara Preparation

# %% [markdown]
# ## Splitting and shuffling data

# %%
np.random.seed(42)

# Use StratifiedShuffleSplit
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.1, random_state=random_seed)

N = len(data)

true_labels = np.array(true_labels)

train_idx, test_idx = next(sss.split(data, true_labels))

x_train, y_train = data[train_idx], true_labels[train_idx]
x_test, y_test = data[test_idx], true_labels[test_idx]

plot_digit_histograms(y_train, y_test)

print(y_test)
# Out:
# [1. 7. 0. 2. 2. 9. 3. 4. 5. 8. 6. 2. 0. 1. 7. 3. 3. 8. 6. 4. 2. 7. 8. 4.
#  0. 7. 8. 5. 3. 6. 5. 1. 4. 8. 9. 9. 1. 9. 7. 8. 1. 4. 2. 3. 7. 6. 5. 2.
#  6. 9. 9. 0. 1. 0. 3. 0. 5. 9. 4.]

# %% [markdown]
# ## Prepare data for torch

# %%
# Move Data to tensors
add_channel = lambda x: x.unsqueeze(1)

x_train_tensor, y_train_tensor = add_channel(torch.from_numpy(x_train)), torch.from_numpy(y_train).long()
x_test_tensor, y_test_tensor = add_channel(torch.from_numpy(x_test)), torch.from_numpy(y_test).long()

# Prepare Dataset
train_set = TensorDataset(x_train_tensor, y_train_tensor)
test_set = TensorDataset(x_test_tensor, y_test_tensor)

# Data loaders
train_batch_size = 16
test_batch_size = len(test_set)

train_loader = torch.utils.data.DataLoader(train_set, batch_size=train_batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=test_batch_size, shuffle=True)

examples = enumerate(train_loader)
batch_idx, (example_data, example_targets) = next(examples)

example_data[0].shape
# Out:
# torch.Size([1, 28, 28])

# %% [markdown]
# ## Define Transform (data augmentation)

# %%
train_transform = torchvision.transforms.Compose([
    torchvision.transforms.RandomRotation(degrees=5),
    torchvision.transforms.RandomAffine(degrees=0, translate=(0.05, 0.05), scale=(0.9, 1.10)),
    torchvision.transforms.ElasticTransform(alpha=5.0, sigma=2.0)
])

# %% [markdown]
# # Loading Model and reasuming training

# %%
from models_arch.recognizer import RecognizerV3ker5 as MyModel

# Hyperparameters
n_epochs = 100
learning_rate = 0.1e-3

# Use GPU acceleration if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Model
PARAMS_PATH = path.join("trained_models", "RecognizerV3ker5.pth")
model = MyModel().to(device)
model.load_state_dict(torch.load(PARAMS_PATH, map_location=device))

# Freeze convolutional layers
for layer in model:
    if isinstance(layer, nn.Conv2d):
        for param in layer.parameters():
            param.requires_grad = False

# Update only the unfrozen layers
optimizer = optim.Adam(filter(lambda p: p.requires_grad, model.parameters()), lr=learning_rate)

criterion = nn.CrossEntropyLoss()  # Change loss function from NLLLoss because model outputs raw logits

train_losses = []
val_losses = []

for epoch in range(n_epochs):
    model.train()
    epoch_loss = []
    for batch_idx, (data, target) in enumerate(train_loader):
        # Apply data augmentation
        data = train_transform(data)

        # Transfer data to GPU
        data, target = data.to(device), target.to(device)

        optimizer.zero_grad()
        output = model(data)

        loss = criterion(output, target)
        epoch_loss.append(loss.item())

        loss.backward()
        optimizer.step()

    # Calculate average loss for the entire epoch
    avg_loss = sum(epoch_loss) / len(epoch_loss)
    train_losses.append(avg_loss)

    # Validate on the test set
    model.eval()
    epoch_val_loss = []

    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            loss = criterion(output, target)
            epoch_val_loss.append(loss.item())
    avg_val_loss = sum(epoch_val_loss) / len(epoch_val_loss)
    val_losses.append(avg_val_loss)

    print(f"Epoch {epoch + 1} | Train loss {avg_loss:.4f} | Validate loss {avg_val_loss:.4f}")

# Training Loss vs Validation Loss (to prevent overfitting)
plt.figure()
plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Validation Loss")
plt.title("Training Loss vs Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()
# Out:
# Epoch 1 | Train loss 0.7439 | Validate loss 0.5006
# Epoch 2 | Train loss 0.7822 | Validate loss 0.4242
# Epoch 3 | Train loss 0.6729 | Validate loss 0.4101
# Epoch 4 | Train loss 0.7732 | Validate loss 0.4298
# Epoch 5 | Train loss 0.5764 | Validate loss 0.4013
# Epoch 6 | Train loss 0.6068 | Validate loss 0.3850
# Epoch 7 | Train loss 0.5534 | Validate loss 0.3790
# Epoch 8 | Train loss 0.5821 | Validate loss 0.3433
# Epoch 9 | Train loss 0.4955 | Validate loss 0.2831
# Epoch 10 | Train loss 0.5057 | Validate loss 0.2940
# Epoch 11 | Train loss 0.5640 | Validate loss 0.3074
# Epoch 12 | Train loss 0.4907 | Validate loss 0.2749
# Epoch 13 | Train loss 0.4684 | Validate loss 0.2703
# Epoch 14 | Train loss 0.3644 | Validate loss 0.2449
# Epoch 15 | Train loss 0.4478 | Validate loss 0.2336
# Epoch 16 | Train loss 0.4894 | Validate loss 0.2090
# Epoch 17 | Train loss 0.4714 | Validate loss 0.2133
# Epoch 18 | Train loss 0.5209 | Validate loss 0.1988
# Epoch 19 | Train loss 0.4983 | Validate loss 0.2288
# Epoch 20 | Train loss 0.3974 | Validate loss 0.2598
# Epoch 21 | Train loss 0.3971 | Validate loss 0.2050
# Epoch 22 | Train loss 0.4051 | Validate loss 0.1670
# Epoch 70 | Train loss 0.2414 | Validate loss 0.0643
# Epoch 71 | Train loss 0.3661 | Validate loss 0.0604
# Epoch 72 | Train loss 0.2306 | Validate loss 0.0474
# Epoch 73 | Train loss 0.2063 | Validate loss 0.0523
# Epoch 74 | Train loss 0.3403 | Validate loss 0.0612
# Epoch 75 | Train loss 0.3390 | Validate loss 0.0540
# Epoch 76 | Train loss 0.1883 | Validate loss 0.0436
# Epoch 77 | Train loss 0.2473 | Validate loss 0.0584
# Epoch 78 | Train loss 0.1893 | Validate loss 0.0521
# Epoch 79 | Train loss 0.2036 | Validate loss 0.0418
# Epoch 80 | Train loss 0.2008 | Validate loss 0.0516
# Epoch 81 | Train loss 0.2460 | Validate loss 0.0442
# Epoch 82 | Train loss 0.1824 | Validate loss 0.0410
# Epoch 83 | Train loss 0.2308 | Validate loss 0.0503
# Epoch 84 | Train loss 0.3892 | Validate loss 0.0420
# Epoch 85 | Train loss 0.2555 | Validate loss 0.0409
# Epoch 86 | Train loss 0.1950 | Validate loss 0.0382
# Epoch 87 | Train loss 0.2086 | Validate loss 0.0645
# Epoch 88 | Train loss 0.1914 | Validate loss 0.0532
# Epoch 89 | Train loss 0.1681 | Validate loss 0.0415
# Epoch 90 | Train loss 0.3171 | Validate loss 0.0333
# Epoch 91 | Train loss 0.2845 | Validate loss 0.0518
# Epoch 92 | Train loss 0.1912 | Validate loss 0.0447
# Epoch 93 | Train loss 0.1853 | Validate loss 0.0398
# Epoch 94 | Train loss 0.1839 | Validate loss 0.0374
# Epoch 95 | Train loss 0.2364 | Validate loss 0.0562
# Epoch 96 | Train loss 0.2311 | Validate loss 0.0407
# Epoch 97 | Train loss 0.1809 | Validate loss 0.0390
# Epoch 98 | Train loss 0.1693 | Validate loss 0.0372
# Epoch 99 | Train loss 0.1769 | Validate loss 0.0357
# Epoch 100 | Train loss 0.2223 | Validate loss 0.0355

# %% [markdown]
# # Model Testing

# %%
# WE CANNOT USE DATA FROM TEST_LOADER BECAUSE OF DATA LEAKAGE RIGHT NOW, IF WE WANT TO TEST THE MODEL'S ACCURACY, WE NEED TO CREATE ADDITIONAL TEST AND VALIDATION SET (RIGHT NOW, DUE TO INSUFFICIENT DATA IN THE CSV FILE FOR FINE-TUNING, IT IS IMPOSSIBLE
# DECOMMENT JUST FOR A QUICK VIEW OF MODEL ACCURACY

model.eval()

# Disable gradient calculation
with torch.no_grad():
    correct = 0
    for (data, target) in test_loader:
        data, target = data.to(device), target.to(device)
        output = model(data)
        y_hat = output.data.max(1, keepdim=True)[1]
        correct += y_hat.eq(target.data.view_as(y_hat)).sum()

accuracy = correct / len(test_set)

print(f"{accuracy=}")
# Out:
# accuracy=tensor(1., device='cuda:0')

# %% [markdown]
# # Saving a model

# %%
torch.save(model.state_dict(), "trained_models/model_fine_tuned.pth")
